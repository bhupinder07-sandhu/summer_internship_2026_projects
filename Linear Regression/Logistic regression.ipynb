# %%
import pandas as pd

# %%
df = pd.read_csv("framingham.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
df.drop(columns ="education",inplace = True)
df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4233     1   50              1         1.0     0.0                0
# 4234     1   51              1        43.0     0.0                0
# 4235     0   48              1        20.0     NaN                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4235             0         0    248.0  131.0   72.0  22.00       84.0
# 4236             0         0    210.0  126.5   87.0  19.16       86.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose  TenYearCHD
# 0        77.0           0
# 1        76.0           0
# 2        70.0           0
# 3       103.0           1
# 4        85.0           0
# ...       ...         ...
# 4233     86.0           1
# 4234     68.0           0
# 4235     86.0           0
# 4236      NaN           0
# 4237    107.0           0
#
# [4238 rows x 15 columns]

# %%
df.describe()
# Out:
#               male          age  currentSmoker   cigsPerDay       BPMeds  \
# count  4238.000000  4238.000000    4238.000000  4209.000000  4185.000000
# mean      0.429212    49.584946       0.494101     9.003089     0.029630
# std       0.495022     8.572160       0.500024    11.920094     0.169584
# min       0.000000    32.000000       0.000000     0.000000     0.000000
# 25%       0.000000    42.000000       0.000000     0.000000     0.000000
# 50%       0.000000    49.000000       0.000000     0.000000     0.000000
# 75%       1.000000    56.000000       1.000000    20.000000     0.000000
# max       1.000000    70.000000       1.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol        sysBP  \
# count      4238.000000   4238.000000  4238.000000  4188.000000  4238.000000
# mean          0.005899      0.310524     0.025720   236.721585   132.352407
# std           0.076587      0.462763     0.158316    44.590334    22.038097
# min           0.000000      0.000000     0.000000   107.000000    83.500000
# 25%           0.000000      0.000000     0.000000   206.000000   117.000000
# 50%           0.000000      0.000000     0.000000   234.000000   128.000000
# 75%           0.000000      1.000000     0.000000   263.000000   144.000000
# max           1.000000      1.000000     1.000000   696.000000   295.000000
#
#              diaBP          BMI    heartRate      glucose   TenYearCHD
# count  4238.000000  4219.000000  4237.000000  3850.000000  4238.000000
# mean     82.893464    25.802008    75.878924    81.966753     0.151958
# std      11.910850     4.080111    12.026596    23.959998     0.359023
# min      48.000000    15.540000    44.000000    40.000000     0.000000
# 25%      75.000000    23.070000    68.000000    71.000000     0.000000
# 50%      82.000000    25.400000    75.000000    78.000000     0.000000
# 75%      89.875000    28.040000    83.000000    87.000000     0.000000
# max     142.500000    56.800000   143.000000   394.000000     1.000000

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.cigsPerDay.mean()
# Out:
# np.float64(9.003088619624615)

# %%
df.cigsPerDay.fillna(9,inplace =True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_5752/648314482.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.cigsPerDay.fillna(9,inplace =True)
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay           0
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.BPMeds.mean()
# Out:
# np.float64(0.02962962962962963)

# %%
df.BPMeds.value_counts()
# Out:
# BPMeds
# 0.0    4061
# 1.0     124
# Name: count, dtype: int64

# %%
df.BPMeds.fillna(0.0,inplace =True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_5752/3602330426.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.BPMeds.fillna(0.0,inplace =True)
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.totChol.value_counts()
# Out:
# totChol
# 240.0    85
# 220.0    70
# 260.0    62
# 210.0    61
# 232.0    59
#          ..
# 392.0     1
# 405.0     1
# 359.0     1
# 398.0     1
# 119.0     1
# Name: count, Length: 248, dtype: int64

# %%
df.totChol.fillna(240.0,inplace =True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_5752/1296440648.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.totChol.fillna(240.0,inplace =True)
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.BMI.value_counts()
# Out:
# BMI
# 22.19    18
# 22.54    18
# 23.48    18
# 22.91    18
# 23.09    16
#          ..
# 34.13     1
# 23.21     1
# 29.13     1
# 19.87     1
# 43.67     1
# Name: count, Length: 1363, dtype: int64

# %%
df.BMI.fillna(22.19,inplace =True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_5752/2300862125.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.BMI.fillna(22.19,inplace =True)
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                  0
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.heartRate.value_counts()
# Out:
# heartRate
# 75.0     563
# 80.0     385
# 70.0     305
# 60.0     231
# 85.0     227
#         ...
# 47.0       1
# 130.0      1
# 140.0      1
# 51.0       1
# 46.0       1
# Name: count, Length: 73, dtype: int64

# %%
df.heartRate.fillna(75.0,inplace=True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_5752/2974009559.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.heartRate.fillna(75.0,inplace=True)
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                  0
# heartRate            0
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.glucose.value_counts()
# Out:
# glucose
# 75.0     193
# 77.0     167
# 73.0     156
# 80.0     152
# 70.0     152
#         ...
# 386.0      1
# 155.0      1
# 147.0      1
# 205.0      1
# 260.0      1
# Name: count, Length: 143, dtype: int64

# %%
df.glucose.fillna(75.0,inplace =True)
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_5752/3991560489.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.glucose.fillna(75.0,inplace =True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df.drop(columns = ["TenYearCHD"],axis = 1)
y = df["TenYearCHD"]
x
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4233     1   50              1         1.0     0.0                0
# 4234     1   51              1        43.0     0.0                0
# 4235     0   48              1        20.0     0.0                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 0                0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0     85.0
# ...            ...       ...      ...    ...    ...    ...        ...      ...
# 4233             1         0    313.0  179.0   92.0  25.97       66.0     86.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0     68.0
# 4235             0         0    248.0  131.0   72.0  22.00       84.0     86.0
# 4236             0         0    210.0  126.5   87.0  19.16       86.0     75.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0    107.0
#
# [4238 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[ 1.16861732,  1.57159684, -0.99823165, ...,  0.31762622,
#         -0.33487187,  0.2047391 ],
#        [ 1.16861732, -0.52730531, -0.99823165, ...,  0.52427238,
#          0.7547474 ,  0.07262841],
#        [-0.85571212,  0.17232874,  1.00177148, ..., -1.35742321,
#         -0.08342127,  0.64510808],
#        ...,
#        [ 1.16861732,  0.05572307, -0.99823165, ...,  0.35895545,
#          0.7547474 ,  0.248776  ],
#        [ 1.16861732,  1.68820251, -0.99823165, ..., -0.22451605,
#          1.59291607, 12.71121804],
#        [ 1.16861732,  0.63875144,  1.00177148, ..., -0.38497071,
#         -0.08342127, -0.41177747]], shape=(848, 14))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
classification=LogisticRegression()
classification.fit(X_train, Y_train)
y_pred=classification.predict(X_test)
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.8573113207547169

# %%
print(classification_report(y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92       833
#            1       0.07      0.60      0.13        15
#
#     accuracy                           0.86       848
#    macro avg       0.53      0.73      0.53       848
# weighted avg       0.98      0.86      0.91       848

# %%
import joblib

joblib.dump(classification, "logistic_model.joblib")
joblib.dump(scaler, "scaler.joblib")
# Out:
# ['scaler.joblib']
