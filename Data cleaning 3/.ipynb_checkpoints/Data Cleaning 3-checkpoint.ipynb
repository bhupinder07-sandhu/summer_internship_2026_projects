# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("youtube recommendation dataset.csv")
df
# Out:
#         user_id  video_id  video_duration  watch_time liked  commented  \
# 0         88263     19387            1499      1499.0     1          0
# 1         46796      5150            2955      2955.0     1          0
# 2         77686      3172             389       389.0     0          0
# 3         26723     27669            1231      1231.0     1          1
# 4         55299     24612            3573       353.0     0          1
# ...         ...       ...             ...         ...   ...        ...
# 999995    30850     24888            2390      1902.0     0          0
# 999996    14324      3681             311       311.0     1          0
# 999997      963     11107            2472      2472.0     1          0
# 999998    87484     40134            1725      1725.0     0          0
# 999999    77920     34283             952       952.0     0          0
#
#         subscribed_after   category   device watch_time_of_day  recommended  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   user_id            1000000 non-null  int64
#  1   video_id           1000000 non-null  int64
#  2   video_duration     1000000 non-null  int64
#  3   watch_time         1000000 non-null  float64
#  4   liked              997952 non-null   object
#  5   commented          1000000 non-null  int64
#  6   subscribed_after   1000000 non-null  int64
#  7   category           1000000 non-null  object
#  8   device             1000000 non-null  object
#  9   watch_time_of_day  1000000 non-null  object
#  10  recommended        1000000 non-null  int64
#  11  clicked            1000000 non-null  int64
#  12  timestamp          1000000 non-null  object
#  13  watch_percent      1000000 non-null  float64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 106.8+ MB

# %%
df.describe()
# Out:
#               user_id        video_id  video_duration      watch_time  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean     50014.595087    25008.932584     1911.577131     1283.683469
# std      28864.277887    14434.546717     3270.284893     2499.074293
# min          1.000000        1.000000        0.000000     -299.000000
# 25%      24998.000000    12503.000000      921.000000      498.000000
# 50%      50048.000000    25020.000000     1816.000000     1071.000000
# 75%      75022.000000    37522.000000     2710.000000     1821.000000
# max     100000.000000    50000.000000   100000.000000   109969.000000
#
#             commented  subscribed_after     recommended         clicked  \
# count  1000000.000000    1000000.000000  1000000.000000  1000000.000000
# mean         0.099497          0.050004        0.399768        0.300771
# std          0.299328          0.217953        0.489851        0.458594
# ...

# %%
df.drop(columns = ["user_id",'video_id',],inplace = True)
df.head()
# Out:
#    video_duration  watch_time liked  commented  subscribed_after   category  \
# 0            1499      1499.0     1          0                 0       News
# 1            2955      2955.0     1          0                 0  Education
# 2             389       389.0     0          0                 0     Sports
# 3            1231      1231.0     1          1                 0     Gaming
# 4            3573       353.0     0          1                 0  Lifestyle
#
#     device watch_time_of_day  recommended  clicked            timestamp  \
# 0       TV             Night            0        0  2025-07-16 06:10:54
# 1   Mobile             Night            1        1  2024-07-09 10:22:22
# 2  Desktop         Afternoon            0        0  2025-02-07 09:46:36
# 3       TV           Evening            0        0  2024-04-28 08:07:13
# 4  Desktop           Evening            1        0  2024-03-30 12:54:24
#
#    watch_percent
# 0       1.000000
# 1       1.000000
# 2       1.000000
# ...

# %%
df.isnull().sum()
# Out:
# video_duration          0
# watch_time              0
# liked                2048
# commented               0
# subscribed_after        0
# category                0
# device                  0
# watch_time_of_day       0
# recommended             0
# clicked                 0
# timestamp               0
# watch_percent           0
# dtype: int64

# %%
df.liked.value_counts()
# Out:
# liked
# 0      696155
# 1      298845
# 2        1007
# no        988
# yes       957
# Name: count, dtype: int64

# %%
df = df[df['liked'] != 'no']
df = df[df['liked'] != 'yes']
df['liked'].fillna(0,inplace= True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_5592/2652148681.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['liked'].fillna(0,inplace= True)
# video_duration       0
# watch_time           0
# liked                0
# commented            0
# subscribed_after     0
# category             0
# device               0
# watch_time_of_day    0
# recommended          0
# clicked              0
# timestamp            0
# watch_percent        0
# dtype: int64

# %%
df.video_duration.unique()
# Out:
# array([1499, 2955,  389, ..., 1746,  387, 1786], shape=(3572,))

# %%
df.watch_time.unique()
# Out:
# array([1499., 2955.,  389., ..., 4466., 9012., 8754.], shape=(5781,))

# %%
df.category.unique()
# Out:
# array(['News', 'Education', 'Sports', 'Gaming', 'Lifestyle', 'Music',
#        'Tech', 'Comedy', 'gamingg', 'MUsic', 'music', 'Ed', 'COMEDY',
#        'Tech '], dtype=object)

# %%
df.device.unique()
# Out:
# array(['TV', 'Mobile', 'Desktop', 'Tablet'], dtype=object)

# %%
df.watch_time_of_day.unique()
# Out:
# array(['Night', 'Afternoon', 'Evening', 'Morning'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        video_duration     watch_time      commented  subscribed_after  \
# count   998055.000000  998055.000000  998055.000000     998055.000000
# mean      1872.975800    1254.228955       0.099492          0.050007
# std       2616.448503    1982.487220       0.299321          0.217960
# min          0.000000    -299.000000       0.000000          0.000000
# 25%        921.000000     498.000000       0.000000          0.000000
# 50%       1815.000000    1069.000000       0.000000          0.000000
# 75%       2710.000000    1817.000000       0.000000          0.000000
# max     100000.000000  109969.000000       1.000000          1.000000
#
#          recommended        clicked  watch_percent
# count  998055.000000  998055.000000   9.980550e+05
# mean        0.399772       0.300779            inf
# std         0.489852       0.458597            NaN
# min         0.000000       0.000000  -2.990000e-03
# 25%         0.000000       0.000000   4.984810e-01
# ...

# %%
df.boxplot(column=['video_duration','commented','subscribed_after','recommended','clicked','watch_percent'])
plt.show()

# %%
import numpy as np

# Select numerical columns
num_cols = df.select_dtypes(include=np.number).columns

# Remove outliers using IQR
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

print("Shape after removing outliers:", df.shape)
# Out:
# Shape after removing outliers: (851439, 12)

# %%
df.boxplot(column=['video_duration','commented','subscribed_after','recommended','clicked','watch_percent'])
plt.show()

# %%
df.boxplot(column=['commented'])
plt.show()

# %%
z
