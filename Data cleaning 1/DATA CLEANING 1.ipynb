# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("dirty_cafe_sales.csv")
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'], errors='coerce')
df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors='coerce')

# %%
df.describe()
# Out:
#           Quantity  Price Per Unit  Total Spent
# count  9521.000000     9467.000000  9498.000000
# mean      3.028463        2.949984     8.924352
# std       1.419007        1.278450     6.009919
# min       1.000000        1.000000     1.000000
# 25%       2.000000        2.000000     4.000000
# 50%       3.000000        3.000000     8.000000
# 75%       4.000000        4.000000    12.000000
# max       5.000000        5.000000    25.000000

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             479
# Price Per Unit       533
# Total Spent          502
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df.drop(columns = ["Transaction ID"],inplace = True)

# %%
df.head()
# Out:
#      Item  Quantity  Price Per Unit  Total Spent  Payment Method  Location  \
# 0  Coffee       2.0             2.0          4.0     Credit Card  Takeaway
# 1    Cake       4.0             3.0         12.0            Cash  In-store
# 2  Cookie       4.0             1.0          NaN     Credit Card  In-store
# 3   Salad       2.0             5.0         10.0         UNKNOWN   UNKNOWN
# 4  Coffee       2.0             2.0          4.0  Digital Wallet  In-store
#
#   Transaction Date
# 0       2023-09-08
# 1       2023-05-16
# 2       2023-07-19
# 3       2023-04-27
# 4       2023-06-11

# %%
df.Item.value_counts()
# Out:
# Item
# Juice       1171
# Coffee      1165
# Salad       1148
# Cake        1139
# Sandwich    1131
# Smoothie    1096
# Cookie      1092
# Tea         1089
# UNKNOWN      344
# ERROR        292
# Name: count, dtype: int64

# %%
df.Item.fillna("Juice",inplace= True)
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_4720/2755887575.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Item.fillna("Juice",inplace= True)

# %%
df.isnull().sum()
# Out:
# Item                   0
# Quantity             479
# Price Per Unit       533
# Total Spent          502
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df.Quantity.value_counts()
# Out:
# Quantity
# 5.0    2013
# 2.0    1974
# 4.0    1863
# 3.0    1849
# 1.0    1822
# Name: count, dtype: int64

# %%
df.Quantity.fillna(5,inplace= True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_4720/3894637047.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Quantity.fillna(5,inplace= True)
# Item                   0
# Quantity               0
# Price Per Unit       533
# Total Spent          502
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df["Price Per Unit"].value_counts()
# Out:
# Price Per Unit
# 3.0    2429
# 4.0    2331
# 2.0    1227
# 5.0    1204
# 1.0    1143
# 1.5    1133
# Name: count, dtype: int64

# %%
df['Price Per Unit'].fillna(3.0,inplace= True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_4720/2099313647.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price Per Unit'].fillna(3.0,inplace= True)
# Item                   0
# Quantity               0
# Price Per Unit         0
# Total Spent          502
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df["Total Spent"].value_counts()
# Out:
# Total Spent
# 6.0     979
# 12.0    939
# 3.0     930
# 4.0     923
# 20.0    746
# 15.0    734
# 8.0     677
# 10.0    524
# 2.0     497
# 9.0     479
# 5.0     468
# 16.0    444
# 25.0    259
# 7.5     237
# 1.0     232
# 4.5     225
# 1.5     205
# Name: count, dtype: int64

# %%
df['Total Spent'].fillna(6.0,inplace= True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_4720/3624529192.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total Spent'].fillna(6.0,inplace= True)
# Item                   0
# Quantity               0
# Price Per Unit         0
# Total Spent            0
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df["Payment Method"].value_counts()
# Out:
# Payment Method
# Digital Wallet    2291
# Credit Card       2273
# Cash              2258
# ERROR              306
# UNKNOWN            293
# Name: count, dtype: int64

# %%
df = df[df['Payment Method'] != 'UNKNOWN']
df = df[df['Payment Method'] != 'ERROR']
df['Payment Method'].fillna("Digital Wallet",inplace= True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_4720/1673954318.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Payment Method'].fillna("Digital Wallet",inplace= True)
# Item                   0
# Quantity               0
# Price Per Unit         0
# Total Spent            0
# Payment Method         0
# Location            3039
# Transaction Date     151
# dtype: int64

# %%
df["Location"].value_counts()
# Out:
# Location
# Takeaway    2859
# In-store    2848
# ERROR        339
# UNKNOWN      316
# Name: count, dtype: int64

# %%
df = df[df['Location'] != 'UNKNOWN']
df = df[df['Location'] != 'ERROR']
df['Location'].fillna("In-store",inplace= True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_4720/565636352.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Location'].fillna("In-store",inplace= True)
# Item                  0
# Quantity              0
# Price Per Unit        0
# Total Spent           0
# Payment Method        0
# Location              0
# Transaction Date    138
# dtype: int64

# %%
df["Transaction Date"].value_counts()
# Out:
# Transaction Date
# UNKNOWN       143
# ERROR         123
# 2023-02-06     36
# 2023-09-21     36
# 2023-06-30     36
#              ...
# 2023-07-30     13
# 2023-02-23     13
# 2023-07-22     13
# 2023-11-24     11
# 2023-04-27     10
# Name: count, Length: 367, dtype: int64

# %%
df = df[df['Transaction Date'] != 'UNKNOWN']
df = df[df['Transaction Date'] != 'ERROR']
df['Transaction Date'].fillna("2023-02-06",inplace= True)
df.isnull().sum()
# Out:
# /var/folders/cn/typknvzx0rqc0bg_wj2zt_t00000gn/T/ipykernel_4720/3018921929.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Transaction Date'].fillna("2023-02-06",inplace= True)
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df.head()
# Out:
#        Item  Quantity  Price Per Unit  Total Spent  Payment Method  Location  \
# 0    Coffee       2.0             2.0          4.0     Credit Card  Takeaway
# 1      Cake       4.0             3.0         12.0            Cash  In-store
# 2    Cookie       4.0             1.0          6.0     Credit Card  In-store
# 4    Coffee       2.0             2.0          4.0  Digital Wallet  In-store
# 5  Smoothie       5.0             4.0         20.0     Credit Card  In-store
#
#   Transaction Date
# 0       2023-09-08
# 1       2023-05-16
# 2       2023-07-19
# 4       2023-06-11
# 5       2023-03-31

# %%
df.duplicated().sum()
# Out:
# np.int64(340)

# %%
df.drop_duplicates(ignore_index=True,inplace = True)

# %%
df
# Out:
#           Item  Quantity  Price Per Unit  Total Spent  Payment Method  \
# 0       Coffee       2.0             2.0          4.0     Credit Card
# 1         Cake       4.0             3.0         12.0            Cash
# 2       Cookie       4.0             1.0          6.0     Credit Card
# 3       Coffee       2.0             2.0          4.0  Digital Wallet
# 4     Smoothie       5.0             4.0         20.0     Credit Card
# ...        ...       ...             ...          ...             ...
# 8135   UNKNOWN       4.0             4.0         16.0  Digital Wallet
# 8136     Juice       3.0             3.0          3.0  Digital Wallet
# 8137    Coffee       4.0             2.0          8.0  Digital Wallet
# 8138    Cookie       3.0             3.0          3.0  Digital Wallet
# 8139  Sandwich       3.0             4.0         12.0            Cash
#
#       Location Transaction Date
# 0     Takeaway       2023-09-08
# 1     In-store       2023-05-16
# ...

# %%
df.describe()
# Out:
#           Quantity  Price Per Unit  Total Spent
# count  8140.000000     8140.000000  8140.000000
# mean      3.126044        2.955160     8.786548
# std       1.444075        1.249678     5.903230
# min       1.000000        1.000000     1.000000
# 25%       2.000000        2.000000     4.000000
# 50%       3.000000        3.000000     7.500000
# 75%       4.000000        4.000000    12.000000
# max       5.000000        5.000000    25.000000

# %%
df.boxplot(column=['Price Per Unit','Quantity','Total Spent'])
plt.show()

# %%
import pandas as pd
import numpy as np

# Select numerical columns
num_cols = df.select_dtypes(include=np.number).columns

# Remove outliers using IQR
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

print("Shape after removing outliers:", df.shape)
# Out:
# Shape after removing outliers: (7926, 7)

# %%
df.boxplot(column=['Price Per Unit','Quantity','Total Spent'])
plt.show()
