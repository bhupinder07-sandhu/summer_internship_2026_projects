# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import  LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import pandas as pd
import seaborn as sns
df = pd.read_csv('loan_approval_dataset.csv')
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.drop(columns ="loan_id",inplace = True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0    no_of_dependents          4269 non-null   int64
#  1    education                 4269 non-null   object
#  2    self_employed             4269 non-null   object
#  3    income_annum              4269 non-null   int64
#  4    loan_amount               4269 non-null   int64
#  5    loan_term                 4269 non-null   int64
#  6    cibil_score               4269 non-null   int64
#  7    residential_assets_value  4269 non-null   int64
#  8    commercial_assets_value   4269 non-null   int64
#  9    luxury_assets_value       4269 non-null   int64
#  10   bank_asset_value          4269 non-null   int64
#  11   loan_status               4269 non-null   object
# dtypes: int64(9), object(3)
# memory usage: 400.3+ KB

# %%
df.describe()
# Out:
#        no_of_dependents  income_annum   loan_amount    loan_term  cibil_score  \
# count       4269.000000  4.269000e+03  4.269000e+03  4269.000000  4269.000000
# mean           2.498712  5.059124e+06  1.513345e+07    10.900445   599.936051
# std            1.695910  2.806840e+06  9.043363e+06     5.709187   172.430401
# min            0.000000  2.000000e+05  3.000000e+05     2.000000   300.000000
# 25%            1.000000  2.700000e+06  7.700000e+06     6.000000   453.000000
# 50%            3.000000  5.100000e+06  1.450000e+07    10.000000   600.000000
# 75%            4.000000  7.500000e+06  2.150000e+07    16.000000   748.000000
# max            5.000000  9.900000e+06  3.950000e+07    20.000000   900.000000
#
#        residential_assets_value  commercial_assets_value  luxury_assets_value  \
# count              4.269000e+03             4.269000e+03         4.269000e+03
# mean               7.472617e+06             4.973155e+06         1.512631e+07
# ...

# %%
df.isnull().sum()
# Out:
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import numpy as np
num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]

print(df.shape)
# Out:
# (4173, 12)

# %%
df.columns = df.columns.str.strip()

print(df.columns)
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
le_education = LabelEncoder()
le_self_employed = LabelEncoder()
le_loan_status = LabelEncoder()
df['self_employed'] = le_self_employed.fit_transform(df['self_employed'])
df['education'] = le_education.fit_transform(df['education'])
df['loan_status'] = le_loan_status.fit_transform(df['loan_status'])

df
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 1                    0          1              1       4100000     12200000
# 2                    3          0              0       9100000     29700000
# 3                    3          0              0       8200000     30700000
# 4                    5          1              1       9800000     24200000
# 5                    0          0              1       4800000     13500000
# ...                ...        ...            ...           ...          ...
# 4264                 5          0              1       1000000      2300000
# 4265                 0          1              1       3300000     11300000
# 4266                 2          1              0       6500000     23900000
# 4267                 1          1              0       4100000     12800000
# 4268                 1          0              0       9200000     29700000
#
# ...

# %%
x_loan_amount = df[['no_of_dependents', 'education', 'self_employed', 'income_annum', 'loan_term', 'cibil_score', 'residential_assets_value',
       'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']]

y_loan_amount = df['loan_amount']

# %%
X_train_loan_amount , X_test_loan_amount , y_train_loan_amount, y_test_loan_amount = train_test_split(x_loan_amount , y_loan_amount , test_size = 0.2 , random_state = 42)
X_train_loan_amount
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_term  \
# 567                  5          0              1       3000000         12
# 3140                 1          0              1       3800000         12
# 2458                 2          0              0       2500000         20
# 2002                 3          0              0       5500000         14
# 1992                 0          1              1       7300000         12
# ...                ...        ...            ...           ...        ...
# 3520                 3          1              0       6900000          4
# 478                  3          1              1       3600000          8
# 3162                 1          0              1       9400000         12
# 3854                 0          1              1       3100000          8
# 877                  1          0              0       5200000          6
#
#       cibil_score  residential_assets_value  commercial_assets_value  \
# ...

# %%
loan_amount_model=RandomForestRegressor(
    n_estimators = 100,
    random_state= 42
)
loan_amount_model.fit(X_train_loan_amount,y_train_loan_amount)
y_pred =loan_amount_model.predict(X_test_loan_amount)
score = r2_score(y_test_loan_amount,y_pred)
print(score)
# Out:
# 0.8497769575533415

# %%
loan_amount_model.score(X_train_loan_amount,y_train_loan_amount)
# Out:
# 0.9791378784736221
